# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time

options = Options()

options.add_argument("--start-maximized")

options.add_argument(
"user-agent=Mozilla/5.0"
)

driver = webdriver.Chrome(options=options)

driver.get("https://www.pict.edu/")

time.sleep(10)

soup = BeautifulSoup(driver.page_source,"html.parser")

for i in soup.find_all("a")[:20]:

    text = i.text.strip()

    if text:

        print(text)

        print("-"*30)

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[7], line 20
#      16 driver.get("https://www.pict.edu/")
#      18 time.sleep(10)
# ---> 20 soup = BeautifulSoup(driver.page_source,"html.parser")
#      22 for i in soup.find_all("a")[:20]:
#      24     text = i.text.strip()
#
# File ~/.local/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:565, in WebDriver.page_source(self)
#     562 @property
#     563 def page_source(self) -> str:
#     564     """Gets the source of the current page."""
# --> 565     return self.execute(Command.GET_PAGE_SOURCE)["value"]
#
# File ~/.local/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:450, in WebDriver.execute(self, driver_command, params)
#     447 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     449 if response:
# --> 450     self.error_handler.check_response(response)
#     451     response["value"] = self._unwrap_value(response.get("value", None))
#     452     return response
#
# File ~/.local/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)
# --> 232 raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message: invalid session id: session deleted as the browser has closed the connection
# from disconnected: not connected to DevTools
#   (Session info: chrome=148.0.7778.167); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# #0 0x568688a6f22a <unknown>
# #1 0x56868846dab9 <unknown>
# #2 0x568688453803 <unknown>
# #3 0x56868847ce06 <unknown>
# #4 0x5686884eff40 <unknown>
# #5 0x568688509ab8 <unknown>
# #6 0x5686884b5662 <unknown>
# #7 0x5686884b6451 <unknown>
# #8 0x568688a32d8b <unknown>
# #9 0x568688a35c65 <unknown>
# #10 0x568688a1f458 <unknown>
# #11 0x568688a367f0 <unknown>
# #12 0x568688a061c0 <unknown>
# #13 0x568688a5c168 <unknown>
# #14 0x568688a5c305 <unknown>
# #15 0x568688a6dc5e <unknown>
# #16 0x71f5a709caa4 <unknown>
# #17 0x71f5a7129c6c <unknown>
